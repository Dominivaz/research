# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
### order = phi, theta, freq, s11
### every 201 is a new degree inc
### s11 in dB
### power transmitted is 1W
s11_t = np.loadtxt('data/S11_Transmitter.csv', delimiter=',', skiprows=1)
s11_aut = np.loadtxt('data/S11_AUT.csv', delimiter=',', skiprows=1)
s11_atot = np.loadtxt('data/S12_AUT_to_Trans.csv', delimiter=',', skiprows=1)
inc = 201

# %%
s11_t.shape
# Out:
# (72561, 4)

# %%
plt.figure()
plt.plot(s11_t[:inc, 2], s11_t[:inc, 3])
# plt.xlim(0, 201)
plt.show()
